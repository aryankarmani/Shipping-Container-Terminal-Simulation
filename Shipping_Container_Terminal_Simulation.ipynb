# %%
# Shipping Container Terminal Simulation: Simulate a shipping container terminal's operations, where containers arrive on ships and are moved around the terminal by cranes and trucks, and different constraints (e.g. container sizes, crane availability) affect the efficiency of operations.
import simpy
import random

class ContainerTerminal:
    def __init__(self, env, num_berths, num_cranes, service_time, waiting_area_capacity):
        self.env = env
        self.berths = simpy.Resource(env, num_berths)
        self.cranes = simpy.Resource(env, num_cranes)
        self.service_time = service_time
        self.waiting_area = simpy.Container(env, waiting_area_capacity, init=0)
        self.wait_times = []
    
    def unload_ship(self, ship):
        with self.berths.request() as berth_req:
            print(f"{ship} arrives at the terminal at {self.env.now}")
            yield berth_req
            print(f"{ship} docks at the berth at {self.env.now}")
            with self.cranes.request() as crane_req:
                yield crane_req
                print(f"Cranes start unloading containers from  {ship} at {self.env.now}")
                yield self.env.timeout(random.normalvariate(self.service_time, 0.5))
                print(f"Cranes finish unloading containers from  {ship} at {self.env.now}")
            self.waiting_area.put(20)  # Assumes 20 containers are unloaded from the ship
            print(f"{ship} leaves the berth at {self.env.now}")
    
    def load_truck(self, truck):
        with self.waiting_area.get(1) as req:
            print(f"{truck} arrives at the terminal at {self.env.now}")
            yield req
            print(f"{truck} starts loading container from the waiting area at {self.env.now}")
            yield self.env.timeout(random.normalvariate(self.service_time, 0.5))
            self.wait_times.append(self.env.now)
            print(f"{truck} leaves the terminal with container at {self.env.now}")
            
env = simpy.Environment()
terminal = ContainerTerminal(env, num_berths=2, num_cranes=3, service_time=10, waiting_area_capacity=100)

for i in range(5):
    env.process(terminal.unload_ship(f"Ship {i+1}"))
for i in range(20):
    env.process(terminal.load_truck(f"Truck {i+1}"))

env.run(until=400)
average_wait_time = sum(terminal.wait_times) / len(terminal.wait_times)
print(f"Average wait time: {average_wait_time:.2f} minutes")
# Out:
# Ship 1 arrives at the terminal at 0
# Ship 2 arrives at the terminal at 0
# Ship 3 arrives at the terminal at 0
# Ship 4 arrives at the terminal at 0
# Ship 5 arrives at the terminal at 0
# Truck 1 arrives at the terminal at 0
# Truck 2 arrives at the terminal at 0
# Truck 3 arrives at the terminal at 0
# Truck 4 arrives at the terminal at 0
# Truck 5 arrives at the terminal at 0
# Truck 6 arrives at the terminal at 0
# Truck 7 arrives at the terminal at 0
# Truck 8 arrives at the terminal at 0
# Truck 9 arrives at the terminal at 0
# Truck 10 arrives at the terminal at 0
# Truck 11 arrives at the terminal at 0
# Truck 12 arrives at the terminal at 0
# Truck 13 arrives at the terminal at 0
# Truck 14 arrives at the terminal at 0
# Truck 15 arrives at the terminal at 0
# Truck 16 arrives at the terminal at 0
# Truck 17 arrives at the terminal at 0
# Truck 18 arrives at the terminal at 0
# Truck 19 arrives at the terminal at 0
# Truck 20 arrives at the terminal at 0
# Ship 1 docks at the berth at 0
# Ship 2 docks at the berth at 0
# Cranes start unloading containers from  Ship 1 at 0
# Cranes start unloading containers from  Ship 2 at 0
# Cranes finish unloading containers from  Ship 2 at 9.584209263460869
# Ship 2 leaves the berth at 9.584209263460869
# Truck 1 starts loading container from the waiting area at 9.584209263460869
# Truck 2 starts loading container from the waiting area at 9.584209263460869
# Truck 3 starts loading container from the waiting area at 9.584209263460869
# Truck 4 starts loading container from the waiting area at 9.584209263460869
# Truck 5 starts loading container from the waiting area at 9.584209263460869
# Truck 6 starts loading container from the waiting area at 9.584209263460869
# Truck 7 starts loading container from the waiting area at 9.584209263460869
# Truck 8 starts loading container from the waiting area at 9.584209263460869
# Truck 9 starts loading container from the waiting area at 9.584209263460869
# Truck 10 starts loading container from the waiting area at 9.584209263460869
# Truck 11 starts loading container from the waiting area at 9.584209263460869
# Truck 12 starts loading container from the waiting area at 9.584209263460869
# Truck 13 starts loading container from the waiting area at 9.584209263460869
# Truck 14 starts loading container from the waiting area at 9.584209263460869
# Truck 15 starts loading container from the waiting area at 9.584209263460869
# Truck 16 starts loading container from the waiting area at 9.584209263460869
# Truck 17 starts loading container from the waiting area at 9.584209263460869
# Truck 18 starts loading container from the waiting area at 9.584209263460869
# Truck 19 starts loading container from the waiting area at 9.584209263460869
# Truck 20 starts loading container from the waiting area at 9.584209263460869
# Ship 3 docks at the berth at 9.584209263460869
# Cranes start unloading containers from  Ship 3 at 9.584209263460869
# Cranes finish unloading containers from  Ship 1 at 9.617395311232665
# Ship 1 leaves the berth at 9.617395311232665
# Ship 4 docks at the berth at 9.617395311232665
# Cranes start unloading containers from  Ship 4 at 9.617395311232665
# Truck 20 leaves the terminal with container at 18.237878445126277
# Truck 7 leaves the terminal with container at 18.572591374999483
# Truck 18 leaves the terminal with container at 18.61040576967614
# Truck 10 leaves the terminal with container at 19.007118604464644
# Truck 16 leaves the terminal with container at 19.03704303355194
# Truck 8 leaves the terminal with container at 19.22166800980305
# Truck 6 leaves the terminal with container at 19.254709929876327
# Truck 11 leaves the terminal with container at 19.334210968017977
# Truck 19 leaves the terminal with container at 19.335306832753105
# Truck 1 leaves the terminal with container at 19.554375263276462
# Truck 5 leaves the terminal with container at 19.59981524498523
# Cranes finish unloading containers from  Ship 3 at 19.64613339060056
# Ship 3 leaves the berth at 19.64613339060056
# Ship 5 docks at the berth at 19.64613339060056
# Cranes start unloading containers from  Ship 5 at 19.64613339060056
# Truck 12 leaves the terminal with container at 19.729617808208225
# Truck 17 leaves the terminal with container at 19.774343397332515
# Truck 3 leaves the terminal with container at 19.948113175839325
# Truck 2 leaves the terminal with container at 19.97694402031368
# Truck 9 leaves the terminal with container at 20.119906983525837
# Truck 15 leaves the terminal with container at 20.160917655690618
# Truck 14 leaves the terminal with container at 20.17841611528278
# Cranes finish unloading containers from  Ship 4 at 20.181922660408784
# Ship 4 leaves the berth at 20.181922660408784
# Truck 4 leaves the terminal with container at 20.28818457271734
# Truck 13 leaves the terminal with container at 20.299593888709623
# Cranes finish unloading containers from  Ship 5 at 30.089400412654925
# Ship 5 leaves the berth at 30.089400412654925
# Average wait time: 19.51 minutes
